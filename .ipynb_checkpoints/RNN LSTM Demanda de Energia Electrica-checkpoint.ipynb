# ...             ...            ...            ...            ...            ...            ...
# 2311       2781.000       2868.000       2943.000       3026.000       3085.000       3129.000
# 2312       2557.000       2635.000       2731.000       2842.000       2915.000       2970.000
# 2313       2492.000       2554.000       2622.000       2706.000       2788.000       2845.000
# 2314       2760.000       2825.000       2897.000       3011.000       3077.000       3126.000
# 2315       2794.000       2870.000       2954.000       3075.000       3181.000       3219.000
#
#       DEM_GCRNO_H17  DEM_GCRNO_H18  DEM_GCRNO_H19  DEM_GCRNO_H20  DEM_GCRNO_H21  DEM_GCRNO_H22  \
# 0          1390.990       1469.534       1620.665       1647.553       1633.332       1591.287
# 1          1717.034       1760.571       1861.713       1862.586       1820.332       1750.791
# 2          1670.032       1724.760       1866.993       1849.466       1813.672       1757.484
# 3          1605.015       1647.744       1814.289       1832.375       1812.007       1752.897
# 4          1814.675       1846.025       1959.640       1958.427       1923.634       1841.551
# ...             ...            ...            ...            ...            ...            ...
# 2311       3105.000       3011.000       2903.000       2962.000       2993.000       3013.000
# 2312       2984.000       2934.000       2848.000       2920.000       2968.000       2966.000
# 2313       2843.000       2793.000       2734.000       2867.000       2966.000       2994.000
# 2314       3105.000       2999.000       2887.000       2985.000       3058.000       3080.000
# 2315       3184.000       3088.000       2982.000       3082.000       3152.000       3167.000
#
#       DEM_GCRNO_H23
# 0          1522.941
# 1          1683.802
# 2          1695.193
# 3          1654.567
# 4          1755.341
# ...             ...
# 2311       2972.000
# 2312       2908.000
# 2313       2948.000
# 2314       3023.000
# 2315       3116.013
#
# [2316 rows x 25 columns]

# %%
#realizando trasnposicion con stack, colocando los nombres correspondientes a las nuevas columnas
consumo_data = consumo_data.set_index('FECHA')
consumo_data = pd.concat([consumo_data.stack()], axis=1)
consumo_data.columns = ['DEMANDA']
consumo_data = consumo_data.reset_index().rename(columns={'level_1': 'HORA'})
consumo_data
# Out:
#            FECHA           HORA   DEMANDA
# 0     2015-01-01   DEM_GCRNO_H0  1568.654
# 1     2015-01-01   DEM_GCRNO_H1  1514.656
# 2     2015-01-01   DEM_GCRNO_H2  1475.261
# 3     2015-01-01   DEM_GCRNO_H3  1444.489
# 4     2015-01-01   DEM_GCRNO_H4  1411.600
# ...          ...            ...       ...
# 55579 2021-05-04  DEM_GCRNO_H19  2982.000
# 55580 2021-05-04  DEM_GCRNO_H20  3082.000
# 55581 2021-05-04  DEM_GCRNO_H21  3152.000
# 55582 2021-05-04  DEM_GCRNO_H22  3167.000
# 55583 2021-05-04  DEM_GCRNO_H23  3116.013
#
# [55584 rows x 3 columns]

# %%
#cambiando las horas de H1..Hn a formato de horas
hora_group = list(consumo_data.HORA.unique())
hora_group
horas = ['0:00','1:00', '2:00', '3:00', '4:00', '5:00', '6:00', 
         '7:00', '8:00', '9:00', '10:00', '11:00', '12:00',
         '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', 
         '19:00', '20:00', '21:00', '22:00', '23:00']
consumo_data['HORA'].replace(hora_group, horas, inplace=True)
consumo_data
# Out:
#            FECHA   HORA   DEMANDA
# 0     2015-01-01   0:00  1568.654
# 1     2015-01-01   1:00  1514.656
# 2     2015-01-01   2:00  1475.261
# 3     2015-01-01   3:00  1444.489
# 4     2015-01-01   4:00  1411.600
# ...          ...    ...       ...
# 55579 2021-05-04  19:00  2982.000
# 55580 2021-05-04  20:00  3082.000
# 55581 2021-05-04  21:00  3152.000
# 55582 2021-05-04  22:00  3167.000
# 55583 2021-05-04  23:00  3116.013
#
# [55584 rows x 3 columns]

# %%
consumo_data['FECHA_new'] = consumo_data['FECHA'].astype(str)
consumo_data["FECHA-HORA"] = consumo_data["FECHA_new"] +' '+ consumo_data["HORA"]
consumo_data["FECHA-HORA"] = pd.to_datetime(consumo_data["FECHA-HORA"])
consumo_data
# Out:
#            FECHA   HORA   DEMANDA   FECHA_new          FECHA-HORA
# 0     2015-01-01   0:00  1568.654  2015-01-01 2015-01-01 00:00:00
# 1     2015-01-01   1:00  1514.656  2015-01-01 2015-01-01 01:00:00
# 2     2015-01-01   2:00  1475.261  2015-01-01 2015-01-01 02:00:00
# 3     2015-01-01   3:00  1444.489  2015-01-01 2015-01-01 03:00:00
# 4     2015-01-01   4:00  1411.600  2015-01-01 2015-01-01 04:00:00
# ...          ...    ...       ...         ...                 ...
# 55579 2021-05-04  19:00  2982.000  2021-05-04 2021-05-04 19:00:00
# 55580 2021-05-04  20:00  3082.000  2021-05-04 2021-05-04 20:00:00
# 55581 2021-05-04  21:00  3152.000  2021-05-04 2021-05-04 21:00:00
# 55582 2021-05-04  22:00  3167.000  2021-05-04 2021-05-04 22:00:00
# 55583 2021-05-04  23:00  3116.013  2021-05-04 2021-05-04 23:00:00
#
# [55584 rows x 5 columns]

# %%
consumo_data.dtypes
# Out:
# FECHA         datetime64[ns]
# HORA                  object
# DEMANDA              float64
# FECHA_new             object
# FECHA-HORA    datetime64[ns]
# dtype: object

# %%
consumo_data = consumo_data[["FECHA-HORA", "DEMANDA"]]
consumo_data
# Out:
#                FECHA-HORA   DEMANDA
# 0     2015-01-01 00:00:00  1568.654
# 1     2015-01-01 01:00:00  1514.656
# 2     2015-01-01 02:00:00  1475.261
# 3     2015-01-01 03:00:00  1444.489
# 4     2015-01-01 04:00:00  1411.600
# ...                   ...       ...
# 55579 2021-05-04 19:00:00  2982.000
# 55580 2021-05-04 20:00:00  3082.000
# 55581 2021-05-04 21:00:00  3152.000
# 55582 2021-05-04 22:00:00  3167.000
# 55583 2021-05-04 23:00:00  3116.013
#
# [55584 rows x 2 columns]

# %%
datos = len(consumo_data)
datos
# Out:
# 55584

# %%
ochenta = datos*0.8
ochenta
# Out:
# 44467.200000000004

# %%
consumo_data.iloc[0:44467,:]
# Out:
#                FECHA-HORA   DEMANDA
# 0     2015-01-01 00:00:00  1568.654
# 1     2015-01-01 01:00:00  1514.656
# 2     2015-01-01 02:00:00  1475.261
# 3     2015-01-01 03:00:00  1444.489
# 4     2015-01-01 04:00:00  1411.600
# ...                   ...       ...
# 44462 2020-01-27 14:00:00  2294.000
# 44463 2020-01-27 15:00:00  2303.000
# 44464 2020-01-27 16:00:00  2307.000
# 44465 2020-01-27 17:00:00  2282.000
# 44466 2020-01-27 18:00:00  2237.000
#
# [44467 rows x 2 columns]

# %%
train_data_qty = len(consumo_data[consumo_data["FECHA-HORA"] < '2020-01-27 00:00:00'])
train_data_qty
# Out:
# 44448

# %%
consumo_data.set_index("FECHA-HORA", inplace=True)
consumo_data=consumo_data.asfreq('h')
consumo_data
# Out:
#                       DEMANDA
# FECHA-HORA
# 2015-01-01 00:00:00  1568.654
# 2015-01-01 01:00:00  1514.656
# 2015-01-01 02:00:00  1475.261
# 2015-01-01 03:00:00  1444.489
# 2015-01-01 04:00:00  1411.600
# ...                       ...
# 2021-05-04 19:00:00  2982.000
# 2021-05-04 20:00:00  3082.000
# 2021-05-04 21:00:00  3152.000
# 2021-05-04 22:00:00  3167.000
# 2021-05-04 23:00:00  3116.013
#
# [55584 rows x 1 columns]

# %%
consumo_data.isna().sum()
# Out:
# DEMANDA    0
# dtype: int64

# %%
consumo_data.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='FECHA-HORA'>

# %%
results = seasonal_decompose(consumo_data["DEMANDA"])
results.observed.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='FECHA-HORA'>

# %%
results.trend.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='FECHA-HORA'>

# %%
results.seasonal.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='FECHA-HORA'>

# %%
results.resid.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='FECHA-HORA'>

# %% [markdown]
# ### Train Test Split

# %%
registros = len(consumo_data)
registros
# Out:
# 55584

# %%
dias = len(consumo_data)/24
dias
# Out:
# 2316.0

# %%
years = dias/365
years
# Out:
# 6.345205479452055

# %%
train_set = consumo_data.iloc[:train_data_qty]
test_set = consumo_data[train_data_qty:]

# %% [raw]
# test_set

# %%
train_set
# Out:
#                       DEMANDA
# FECHA-HORA
# 2015-01-01 00:00:00  1568.654
# 2015-01-01 01:00:00  1514.656
# 2015-01-01 02:00:00  1475.261
# 2015-01-01 03:00:00  1444.489
# 2015-01-01 04:00:00  1411.600
# ...                       ...
# 2020-01-26 19:00:00  2173.000
# 2020-01-26 20:00:00  2188.000
# 2020-01-26 21:00:00  2184.000
# 2020-01-26 22:00:00  2137.000
# 2020-01-26 23:00:00  2050.000
#
# [44448 rows x 1 columns]

# %%
test_set
# Out:
#                       DEMANDA
# FECHA-HORA
# 2020-01-27 00:00:00  1943.000
# 2020-01-27 01:00:00  1860.000
# 2020-01-27 02:00:00  1818.000
# 2020-01-27 03:00:00  1789.000
# 2020-01-27 04:00:00  1777.000
# ...                       ...
# 2021-05-04 19:00:00  2982.000
# 2021-05-04 20:00:00  3082.000
# 2021-05-04 21:00:00  3152.000
# 2021-05-04 22:00:00  3167.000
# 2021-05-04 23:00:00  3116.013
#
# [11136 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(train_set)
testing_set_scaled = sc.fit_transform(test_set)

# %%
training_set_scaled
# Out:
# array([[0.06036899],
#        [0.046753  ],
#        [0.03681926],
#        ...,
#        [0.21553299],
#        [0.2036816 ],
#        [0.18174391]])

# %% [markdown]
# ## Times Series Generator
# Este generador toma una secuencua de puntos de datos (como una serie temporal) espaciados en intervalos iguales, teniendo en cuenta otros parámetros de series temporales, para producir batches para el entrenamiento /validación

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
n_input = 2
n_features = 1
generator = TimeseriesGenerator(training_set_scaled, training_set_scaled, length = n_input, batch_size=1)

# %%
n_timestamp = 48


#def data_split(sequence, n_timestamp):
#    X = []
#    y = []
#    qtyregistros = len(sequence)
#    for i in range(n_timestamp, qtyregistros):
#       X.append(sequence[i-n_timestamp:i,0])
#       y.append(sequence[i,0])
#    return np.array(X), np.array(y)

def data_split(sequence, n_timestamp):
    X = []
    y = []
    for i in range(len(sequence)):
        end_ix = i + n_timestamp
        if end_ix > len(sequence)-1:
            break
        # i to end_ix as input
        # end_ix as target output
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
X_train, y_train = data_split(training_set_scaled, n_timestamp)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test, y_test = data_split(testing_set_scaled, n_timestamp)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
X_train.shape
# Out:
# (44400, 48, 1)

# %%
X_test.shape
# Out:
# (11088, 48, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Dropout
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from numpy import array

# %%
model = Sequential()
model.add(LSTM(units = 50, activation='relu',input_shape = (X_train.shape[1], 1)))
model.add(Dense(units = 1))

model.compile(loss='mean_squared_error', 
              optimizer='adam')

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=2)
]

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 50)                10400
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs = 25, callbacks=my_callbacks, batch_size = 32)
loss = history.history['loss']
epochs = range(len(loss))
# Out:
# Epoch 1/25
# 1388/1388 [==============================] - 13s 10ms/step - loss: 1.6074e-04
# Epoch 2/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.4938e-04
# Epoch 3/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.3730e-04
# Epoch 4/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.3378e-04
# Epoch 5/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.2859e-04
# Epoch 6/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.2364e-04
# Epoch 7/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.2120e-04
# Epoch 8/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.1342e-04
# Epoch 9/25
# 1388/1388 [==============================] - 13s 10ms/step - loss: 1.0633e-04
# Epoch 10/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.0419e-04
# Epoch 11/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 1.0292e-04
# Epoch 12/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 9.5939e-05
# Epoch 13/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 9.6166e-05
# Epoch 14/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 9.0939e-05
# Epoch 15/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 9.0283e-05
# Epoch 16/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 8.8381e-05
# Epoch 17/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 8.2682e-05
# Epoch 18/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 8.1949e-05
# Epoch 19/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 8.0983e-05
# Epoch 20/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 7.9672e-05
# Epoch 21/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 7.7327e-05
# Epoch 22/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 7.6705e-05
# Epoch 23/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 7.6024e-05
# Epoch 24/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 7.3551e-05
# Epoch 25/25
# 1388/1388 [==============================] - 14s 10ms/step - loss: 7.2229e-05

# %%
#
# Get predicted data
#
y_predicted = model.predict(X_test)

y_predicted
# Out:
# array([[0.14429584],
#        [0.11804352],
#        [0.10566954],
#        ...,
#        [0.4396477 ],
#        [0.4326877 ],
#        [0.42312607]], dtype=float32)

# %%
#
# 'De-normalize' the data
#
y_predicted_descaled = sc.inverse_transform(y_predicted)
y_train_descaled = sc.inverse_transform(y_train)
y_test_descaled = sc.inverse_transform(y_test)
y_pred = y_predicted.ravel()
y_pred = [round(yx, 2) for yx in y_pred]
y_tested = y_test.ravel()

# %%
#
# Show results
#
plt.figure(figsize=(20,5))

plt.subplot(3, 1, 1)
plt.plot(consumo_data['DEMANDA'], color = 'black', linewidth=1, label = 'True value')
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("All data")


plt.subplot(3, 2, 3)
plt.plot(y_test_descaled, color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled, color = 'red',  linewidth=1, label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("Predicted data (n days)")

plt.subplot(3, 2, 4)
plt.plot(y_test_descaled[0:75], color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled[0:75], color = 'red', label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("Predicted data (first 75 days)")

plt.subplot(3, 3, 7)
plt.plot(epochs, loss, color='black')
plt.ylabel("Loss (MSE)")
plt.xlabel("Epoch")
plt.title("Training curve")

plt.subplot(3, 3, 8)
plt.plot(y_test_descaled-y_predicted_descaled, color='black')
plt.ylabel("Residual")
plt.xlabel("Day")
plt.title("Residual plot")

plt.subplot(3, 3, 9)
plt.scatter(y_predicted_descaled, y_test_descaled, s=2, color='black')
plt.ylabel("Y true")
plt.xlabel("Y predicted")
plt.title("Scatter plot")

plt.subplots_adjust(hspace = 0.5, wspace=0.3)
plt.show()



mse = mean_squared_error(y_test_descaled, y_predicted_descaled)
r2 = r2_score(y_test_descaled, y_predicted_descaled)
print("mse=" + str(round(mse,2)))
print("r2=" + str(round(r2,2)))
# Out:
# mse=1124.29
# r2=1.0

# %% [markdown]
# ### MODELO II

# %%
model = Sequential()
model.add(LSTM(units = 50, return_sequences = True, activation='relu',input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.25))
model.add(LSTM(units = 50, return_sequences = True, activation='relu'))
model.add(Dropout(0.25))
model.add(LSTM(units = 50, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(units = 1))

model.compile(loss='mean_squared_error', 
              optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 48, 50)            10400
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 50)            0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 48, 50)            20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 48, 50)            0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs = 25, callbacks=my_callbacks, batch_size = 32)
loss = history.history['loss']
epochs = range(len(loss))
# Out:
# Epoch 1/25
# 1388/1388 [==============================] - 41s 30ms/step - loss: 0.0026
# Epoch 2/25
# 1388/1388 [==============================] - 41s 30ms/step - loss: 0.0019
# Epoch 3/25
# 1388/1388 [==============================] - 42s 30ms/step - loss: 0.0016
# Epoch 4/25
# 1388/1388 [==============================] - 41s 30ms/step - loss: 0.0015
# Epoch 5/25
# 1388/1388 [==============================] - 41s 30ms/step - loss: 0.0014
# Epoch 6/25
# 1388/1388 [==============================] - 42s 30ms/step - loss: 0.0013
# Epoch 7/25
# 1388/1388 [==============================] - 42s 30ms/step - loss: 0.0013
# Epoch 8/25
# 1388/1388 [==============================] - 42s 30ms/step - loss: 0.0013
# Epoch 9/25
# 1388/1388 [==============================] - 42s 30ms/step - loss: 0.0012
# Epoch 10/25
# 1388/1388 [==============================] - 43s 31ms/step - loss: 0.0012
# Epoch 11/25
# 1388/1388 [==============================] - 46s 33ms/step - loss: 0.0012
# Epoch 12/25
# 1388/1388 [==============================] - 45s 33ms/step - loss: 0.0011
# Epoch 13/25
# 1388/1388 [==============================] - 43s 31ms/step - loss: 0.0011
# Epoch 14/25
# 1388/1388 [==============================] - 43s 31ms/step - loss: 0.0011
# Epoch 15/25
# 1388/1388 [==============================] - 43s 31ms/step - loss: 0.0011
# Epoch 16/25
# 1388/1388 [==============================] - 44s 31ms/step - loss: 0.0011
# Epoch 17/25
# 1388/1388 [==============================] - 44s 31ms/step - loss: 0.0011
# Epoch 18/25
# 1388/1388 [==============================] - 44s 31ms/step - loss: 0.0026
# Epoch 19/25
# 1388/1388 [==============================] - 43s 31ms/step - loss: 0.0018

# %%
#
# Get predicted data
#
y_predicted = model.predict(X_test)
# 'De-normalize' the data
#
y_predicted_descaled = sc.inverse_transform(y_predicted)
y_train_descaled = sc.inverse_transform(y_train)
y_test_descaled = sc.inverse_transform(y_test)
y_pred = y_predicted.ravel()
y_pred = [round(yx, 2) for yx in y_pred]
y_tested = y_test.ravel()

# %%
#
# Show results
#
plt.figure(figsize=(20,5))

plt.subplot(3, 1, 1)
plt.plot(consumo_data['DEMANDA'], color = 'black', linewidth=1, label = 'True value')
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("All data")


plt.subplot(3, 2, 3)
plt.plot(y_test_descaled, color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled, color = 'red',  linewidth=1, label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("Predicted data (n days)")

plt.subplot(3, 2, 4)
plt.plot(y_test_descaled[0:75], color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled[0:75], color = 'red', label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("Predicted data (first 75 days)")

plt.subplot(3, 3, 7)
plt.plot(epochs, loss, color='black')
plt.ylabel("Loss (MSE)")
plt.xlabel("Epoch")
plt.title("Training curve")

plt.subplot(3, 3, 8)
plt.plot(y_test_descaled-y_predicted_descaled, color='black')
plt.ylabel("Residual")
plt.xlabel("Day")
plt.title("Residual plot")

plt.subplot(3, 3, 9)
plt.scatter(y_predicted_descaled, y_test_descaled, s=2, color='black')
plt.ylabel("Y true")
plt.xlabel("Y predicted")
plt.title("Scatter plot")

plt.subplots_adjust(hspace = 0.5, wspace=0.3)
plt.show()



mse = mean_squared_error(y_test_descaled, y_predicted_descaled)
r2 = r2_score(y_test_descaled, y_predicted_descaled)
print("mse=" + str(round(mse,2)))
print("r2=" + str(round(r2,2)))
# Out:
# mse=29099.7
# r2=0.96

# %% [markdown]
# ### Modelo III

# %%
model = Sequential()
model.add(LSTM(units = 50, activation='relu', return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.25))
model.add(LSTM(units = 50, activation='relu',input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.25))
model.add(Dense(units = 1))

model.compile(loss='mean_squared_error', 
              optimizer='sgd')

# %%
model.summary()

# %%
history = model.fit(X_train, y_train, epochs = 25, batch_size = 64)
loss = history.history['loss']
epochs = range(len(loss))
# Out:
# Epoch 1/25
# 694/694 [==============================] - 22s 30ms/step - loss: 0.0460
# Epoch 2/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0181
# Epoch 3/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0092
# Epoch 4/25
# 694/694 [==============================] - 20s 29ms/step - loss: 0.0083
# Epoch 5/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0081
# Epoch 6/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0079
# Epoch 7/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0078
# Epoch 8/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0075
# Epoch 9/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0076
# Epoch 10/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0076
# Epoch 11/25
# 694/694 [==============================] - 20s 30ms/step - loss: 0.0075
# Epoch 12/25
# 694/694 [==============================] - 20s 30ms/step - loss: 0.0073
# Epoch 13/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0072
# Epoch 14/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0074
# Epoch 15/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0072
# Epoch 16/25
# 694/694 [==============================] - 21s 31ms/step - loss: 0.0073
# Epoch 17/25
# 694/694 [==============================] - 21s 31ms/step - loss: 0.0072
# Epoch 18/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0071
# Epoch 19/25
# 694/694 [==============================] - 21s 30ms/step - loss: 0.0072
# Epoch 20/25
# 694/694 [==============================] - 22s 32ms/step - loss: 0.0071
# Epoch 21/25
# 694/694 [==============================] - 22s 31ms/step - loss: 0.0070
# Epoch 22/25
# 694/694 [==============================] - 21s 31ms/step - loss: 0.0071
# Epoch 23/25
# 694/694 [==============================] - 22s 31ms/step - loss: 0.0070
# Epoch 24/25
# 694/694 [==============================] - 22s 31ms/step - loss: 0.0070
# Epoch 25/25
# 694/694 [==============================] - 21s 31ms/step - loss: 0.0070

# %%
y_predicted = model.predict(X_test)
#
# 'De-normalize' the data
#
y_predicted_descaled = sc.inverse_transform(y_predicted)
y_train_descaled = sc.inverse_transform(y_train)
y_test_descaled = sc.inverse_transform(y_test)
y_pred = y_predicted.ravel()
y_pred = [round(yx, 2) for yx in y_pred]
y_tested = y_test.ravel()

# %%
#
# Show results
#
plt.figure(figsize=(20,5))

plt.subplot(3, 1, 1)
plt.plot(consumo_data['DEMANDA'], color = 'black', linewidth=1, label = 'True value')
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("All data")


plt.subplot(3, 2, 3)
plt.plot(y_test_descaled, color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled, color = 'red',  linewidth=1, label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("Predicted data (n days)")

plt.subplot(3, 2, 4)
plt.plot(y_test_descaled[0:75], color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled[0:75], color = 'red', label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("Predicted data (first 75 days)")

plt.subplot(3, 3, 7)
plt.plot(epochs, loss, color='black')
plt.ylabel("Loss (MSE)")
plt.xlabel("Epoch")
plt.title("Training curve")

plt.subplot(3, 3, 8)
plt.plot(y_test_descaled-y_predicted_descaled, color='black')
plt.ylabel("Residual")
plt.xlabel("Day")
plt.title("Residual plot")

plt.subplot(3, 3, 9)
plt.scatter(y_predicted_descaled, y_test_descaled, s=2, color='black')
plt.ylabel("Y true")
plt.xlabel("Y predicted")
plt.title("Scatter plot")

plt.subplots_adjust(hspace = 0.5, wspace=0.3)
plt.show()



mse = mean_squared_error(y_test_descaled, y_predicted_descaled)
r2 = r2_score(y_test_descaled, y_predicted_descaled)
print("mse=" + str(round(mse,2)))
print("r2=" + str(round(r2,2)))
# Out:
# mse=105464.17
# r2=0.86

# %% [markdown]
# ### Modelo IV

# %%
model = Sequential()
model.add(LSTM(units = 50, activation='relu', return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.25))
model.add(LSTM(units = 50, activation='sigmoid', return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.25))
model.add(LSTM(units = 50, activation='sigmoid',input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.25))
model.add(Dense(units = 1))

model.compile(loss='mean_squared_error', 
              optimizer='adamax')

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_17 (LSTM)               (None, 48, 50)            10400
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 48, 50)            0
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 48, 50)            20200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 48, 50)            0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs = 25, batch_size = 64)
loss = history.history['loss']
epochs = range(len(loss))
# Out:
# Epoch 1/25
# 694/694 [==============================] - 34s 46ms/step - loss: 0.1506
# Epoch 2/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0308
# Epoch 3/25
# 694/694 [==============================] - 30s 44ms/step - loss: 0.0164
# Epoch 4/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0117
# Epoch 5/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0091
# Epoch 6/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0085
# Epoch 7/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0078
# Epoch 8/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0072
# Epoch 9/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0059
# Epoch 10/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0056
# Epoch 11/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0051
# Epoch 12/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0050
# Epoch 13/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0042
# Epoch 14/25
# 694/694 [==============================] - 31s 45ms/step - loss: 0.0038
# Epoch 15/25
# 694/694 [==============================] - 32s 46ms/step - loss: 0.0037
# Epoch 16/25
# 694/694 [==============================] - 32s 46ms/step - loss: 0.0032
# Epoch 17/25
# 694/694 [==============================] - 32s 46ms/step - loss: 0.0033
# Epoch 18/25
# 694/694 [==============================] - 32s 47ms/step - loss: 0.0030
# Epoch 19/25
# 694/694 [==============================] - 34s 48ms/step - loss: 0.0027
# Epoch 20/25
# 694/694 [==============================] - 34s 48ms/step - loss: 0.0026
# Epoch 21/25
# 694/694 [==============================] - 32s 46ms/step - loss: 0.0025
# Epoch 22/25
# 694/694 [==============================] - 36s 52ms/step - loss: 0.0024
# Epoch 23/25
# 694/694 [==============================] - 37s 53ms/step - loss: 0.0024
# Epoch 24/25
# 694/694 [==============================] - 36s 53ms/step - loss: 0.0023
# Epoch 25/25
# 694/694 [==============================] - 33s 47ms/step - loss: 0.0023

# %%
y_predicted = model.predict(X_test)
#
# 'De-normalize' the data
#
y_predicted_descaled = sc.inverse_transform(y_predicted)
y_train_descaled = sc.inverse_transform(y_train)
y_test_descaled = sc.inverse_transform(y_test)
y_pred = y_predicted.ravel()
y_pred = [round(yx, 2) for yx in y_pred]
y_tested = y_test.ravel()

# %%
#
# Show results
#
plt.figure(figsize=(20,5))

plt.subplot(3, 1, 1)
plt.plot(consumo_data['DEMANDA'], color = 'black', linewidth=1, label = 'True value')
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("All data")


plt.subplot(3, 2, 3)
plt.plot(y_test_descaled, color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled, color = 'red',  linewidth=1, label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("Predicted data (n days)")

plt.subplot(3, 2, 4)
plt.plot(y_test_descaled[0:75], color = 'black', linewidth=1, label = 'True value')
plt.plot(y_predicted_descaled[0:75], color = 'red', label = 'Predicted')
plt.legend(frameon=False)
plt.ylabel("DEMANDA")
plt.xlabel("FECHA-HORA")
plt.title("Predicted data (first 75 days)")

plt.subplot(3, 3, 7)
plt.plot(epochs, loss, color='black')
plt.ylabel("Loss (MSE)")
plt.xlabel("Epoch")
plt.title("Training curve")

plt.subplot(3, 3, 8)
plt.plot(y_test_descaled-y_predicted_descaled, color='black')
plt.ylabel("Residual")
plt.xlabel("Day")
plt.title("Residual plot")

plt.subplot(3, 3, 9)
plt.scatter(y_predicted_descaled, y_test_descaled, s=2, color='black')
plt.ylabel("Y true")
plt.xlabel("Y predicted")
plt.title("Scatter plot")

plt.subplots_adjust(hspace = 0.5, wspace=0.3)
plt.show()



mse = mean_squared_error(y_test_descaled, y_predicted_descaled)
r2 = r2_score(y_test_descaled, y_predicted_descaled)
print("mse=" + str(round(mse,2)))
print("r2=" + str(round(r2,2)))
# Out:
# mse=20196.26
# r2=0.97
